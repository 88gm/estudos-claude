# %%
#Install dependenecies
# %pip install anthropic python-dotenv

# %%
#Load env variables
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
#Create an API client
from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-4-6"

# %%
def add_user_message(messages, text):
    user_message = { "role": "user", "content": text }
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = { "role": "assistant", "content": text }
    messages.append(assistant_message)

def chat(messages):
    message = client.messages.create(
        model=model,
        max_tokens=1000,
        messages=messages,
    )
    return message.content[0].text

# %%
#Make a starting list of messages
messages = []

# Add in the initial user question of "What is the meaning of life? Write in one sentence."
add_user_message(messages, "O que é a vida? Escreva em uma frase.")

# Pass the list of messages into chat to get an answer
answer = chat(messages)

# Take the annswer and add it as an assistant message to the list of messages
add_assistant_message(messages, answer)

# Add in the user's follow-up question
add_user_message(messages, "Escreva outra frase.")

# Call the chat again
answer = chat(messages)

# Take the annswer and add it as an assistant message to the list of messages
add_assistant_message(messages, answer)

messages
# Out:
# [{'role': 'user', 'content': 'O que é a vida? Escreva em uma frase.'},
#  {'role': 'assistant',
#   'content': '**A vida é um processo dinâmico e contínuo de organização, adaptação e reprodução que permite aos seres existirem, interagirem com o ambiente e perpetuarem sua existência.**'},
#  {'role': 'user', 'content': 'Escreva outra frase.'},
#  {'role': 'assistant',
#   'content': '**A vida é a chama que transforma matéria em experiência, conectando cada ser ao fluxo eterno do tempo através do nascimento, do crescimento e da morte.**'}]
